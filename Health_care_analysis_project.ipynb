# %% [markdown]
# # ------------ Health_care_Analysis -----------------

# %%
# Import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('archive (1).zip',parse_dates=['Date of Admission','Discharge Date'])
data
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
data.drop(data[['Name','Doctor','Hospital']],axis=1,inplace=True)
data
# Out:
#       Age  Gender Blood Type Medical Condition Date of Admission  \
# 0      81  Female         O-          Diabetes        2022-11-17
# 1      35    Male         O+            Asthma        2023-06-01
# 2      61    Male         B-           Obesity        2019-01-09
# 3      49    Male         B-            Asthma        2020-05-02
# 4      51    Male         O-         Arthritis        2021-07-09
# ...   ...     ...        ...               ...               ...
# 9995   83    Male         A+           Obesity        2022-07-29
# 9996   47  Female        AB+         Arthritis        2022-01-06
# 9997   54    Male         B-         Arthritis        2022-07-01
# 9998   84    Male         A+         Arthritis        2020-02-06
# 9999   20    Male         B-         Arthritis        2023-03-22
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0              Medicare    37490.983364          146       Elective
# ...

# %%
data['Gender']=data['Gender'].replace({'Female':0, 'Male':1})
data['Blood Type']=data['Blood Type'].replace({'A+':0,'B+':1,'AB+':2,'A-':3,'B-':4,'O-':5,'O+':6})
data['Medical Condition']=data['Medical Condition'].replace({'Diabetes':0, 'Asthma':1, 'Obesity':2, 'Arthritis':3, 'Hypertension':4,
       'Cancer':5})
data['Insurance Provider']=data['Insurance Provider'].replace({'Medicare':0, 'UnitedHealthcare':1, 'Aetna':2, 'Cigna':3, 'Blue Cross':4})
data['Admission Type']=data['Admission Type'].replace({'Elective':0, 'Emergency':1, 'Urgent':2})
data['Medication']=data['Medication'].replace({'Aspirin':0, 'Lipitor':1, 'Penicillin':2, 'Paracetamol':3, 'Ibuprofen':4})
data['Test Results']=data['Test Results'].replace({'Inconclusive':1, 'Normal':1, 'Abnormal':2})

# %%
data
# Out:
#       Age  Gender Blood Type  Medical Condition Date of Admission  \
# 0      81       0          5                  0        2022-11-17
# 1      35       1          6                  1        2023-06-01
# 2      61       1          4                  2        2019-01-09
# 3      49       1          4                  1        2020-05-02
# 4      51       1          5                  3        2021-07-09
# ...   ...     ...        ...                ...               ...
# 9995   83       1          0                  2        2022-07-29
# 9996   47       0          2                  3        2022-01-06
# 9997   54       1          4                  3        2022-07-01
# 9998   84       1          0                  3        2020-02-06
# 9999   20       1          4                  3        2023-03-22
#
#       Insurance Provider  Billing Amount  Room Number  Admission Type  \
# 0                      0    37490.983364          146               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  datetime64[ns]
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  datetime64[ns]
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
frequency_table=data['Admission Type'].value_counts()
frequency_table

# create a bar chart
plt.bar(data[frequency_table.values)
plt.title('Admission Type Frequency')
plt.xlabel('Admission Type')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
frequency_table=data['Admission Type'].value_counts()
frequency_table
# Out:
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: Admission Type, dtype: int64

# %%
plt.hist(data['Room Number'],bins=30,edgecolor='black')
plt.xlabel('Room Number')
plt.ylabel('Frequency')
plt.title('Histogram of Room Number')
plt.show()

# %%
sns.boxplot(y=data['Room Number'])
plt.title('Box plot of Room Number')
plt.show()

# %%
sns.boxplot(data=data,x="Gender",y="Room Number",color="Green")
plt.xticks(rotation=45)
plt.title('Box plot of Room Number by Gender')
plt.show()

# %%
sns.scatterplot(data=data,x="Medical Condition",y="Age",hue="Gender",style="Gender")
plt.legend(bbox_to_anchor=(.5,1.15),loc='center',title='Gender')
plt.show()

# %%
data.corr(method="pearson")
# Out:
#                      Age  Billing Amount  Room Number
# Age             1.000000       -0.009483    -0.005371
# Billing Amount -0.009483        1.000000    -0.006160
# Room Number    -0.005371       -0.006160     1.000000

# %%
a=np.array([3456,3277,3267])
mylabels=['Abnormal','Inclusive','Normal']
plt.pie(a,labels=mylabels)
plt.show()
